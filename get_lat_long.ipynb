# %%
# import libraries
import pandas as pd
import requests
import json

# %% [markdown]
# Read causes of death csv

# %%
df = pd.read_csv('data_files/cause_of_deaths.csv')
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# ...

# %% [markdown]
# API call to mapquest to get latitude and longitude values

# %%
def get_lat_long(df):
    for i, country in enumerate(df['Country/Territory']):
        parameters = {
            'key' : 'NWzfLixXzrP0GAwppmmDDqrTtMf4xVVK',
            'location' : country
        }
        response = requests.get('http://www.mapquestapi.com/geocoding/v1/address', params = parameters)
        data = json.loads(response.text)['results'][0]['locations'][0]['latLng']
            
        lat = data['lat']
        long = data['lng']
        
        df.at[i, 'lat'] = lat
        df.at[i, 'lng'] = long
        
get_lat_long(df)

# %%
df.to_csv('data_files/cause_of_deaths_geo.csv')
